# %%
import torch
import torch.nn as nn

# 모델 클래스 정의 예시
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc = nn.Linear(10, 1)
    def forward(self, x):
        return self.fc(x)

model = MyModel()

# 체크포인트 로드
checkpoint = torch.load('checkpoint.pth')
model.load_state_dict(checkpoint['model_state_dict'])

# 옵티마이저도 저장했다면 같이 불러오기
optimizer = torch.optim.Adam(model.parameters())
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# 학습 epoch 정보 등도 불러오기 가능
start_epoch = checkpoint.get('epoch', 0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 import torch.nn as nn
#       4 # 모델 클래스 정의 예시
#
# ModuleNotFoundError: No module named 'torch'

# %%
# !pip install torch torchvision torchaudio
# Out:
# ...
#   Using cached torch-2.7.1-cp313-cp313-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached torchvision-0.22.1-cp313-cp313-win_amd64.whl.metadata (6.1 kB)
# ...
#   Using cached torchaudio-2.7.1-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
# Using cached torch-2.7.1-cp313-cp313-win_amd64.whl (216.1 MB)
# Using cached torchvision-0.22.1-cp313-cp313-win_amd64.whl (1.7 MB)
# Using cached torchaudio-2.7.1-cp313-cp313-win_amd64.whl (2.5 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached fsspec-2025.7.0-py3-none-any.whl (199 kB)
# ...

# %%
# !pip install torch torchvision torchaudio

# %%
# %pip install torch torchvision torchaudio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
which python
# Out:
#   Cell In[5], line 1
#     which python
#           ^
# SyntaxError: invalid syntax

# %%
import torch
import torch.nn as nn

# 예시 모델 클래스 정의
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc = nn.Linear(10, 1)
    def forward(self, x):
        return self.fc(x)

# 모델 객체 생성
model = MyModel()

# 저장한 체크포인트 경로 (본인 파일명으로 변경)
checkpoint_path = 'checkpoint.pth'

# 체크포인트 로드
checkpoint = torch.load(checkpoint_path)

# 모델 가중치 로드
model.load_state_dict(checkpoint['model_state_dict'])

# 옵티마이저도 저장했다면 같이 불러오기
optimizer = torch.optim.Adam(model.parameters())
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# 저장한 epoch 정보 등 가져오기
start_epoch = checkpoint.get('epoch', 0)

print(f"Checkpoint loaded. Starting from epoch {start_epoch}.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 19
#      16 checkpoint_path = 'checkpoint.pth'
#      18 # 체크포인트 로드
# ---> 19 checkpoint = torch.load(checkpoint_path)
#      21 # 모델 가중치 로드
#      22 model.load_state_dict(checkpoint['model_state_dict'])
#
# File ~\Documents\Smart-energy-optimizer\venv\Lib\site-packages\torch\serialization.py:1479, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1476 if "encoding" not in pickle_load_args.keys():
#    1477     pickle_load_args["encoding"] = "utf-8"
# -> 1479 with _open_file_like(f, "rb") as opened_file:
#    1480     if _is_zipfile(opened_file):
#    1481         # The zipfile reader is going to advance the current file position.
#    1482         # If we want to actually tail call to torch.jit.load, we need to
#    1483         # reset back to the original position.
# ...

# %%
import torch
import torch.nn as nn

# 1. 모델 클래스 정의 (예: LSTM 모델 구조)
class MyLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])  # 마지막 타임스텝 출력 사용
        return out

# 2. 모델 객체 생성 (모델 하이퍼파라미터는 본인이 쓰던 값으로)
model = MyLSTMModel(input_size=10, hidden_size=20, num_layers=2, output_size=1)

# 3. 체크포인트 파일 경로 지정
checkpoint_path = 'checkpoint.pth'  # 실제 경로 맞게 수정

# 4. 체크포인트 불러오기
checkpoint = torch.load(checkpoint_path)
model.load_state_dict(checkpoint['model_state_dict'])

print("체크포인트 불러오기 완료!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 22
#      19 checkpoint_path = 'checkpoint.pth'  # 실제 경로 맞게 수정
#      21 # 4. 체크포인트 불러오기
# ---> 22 checkpoint = torch.load(checkpoint_path)
#      23 model.load_state_dict(checkpoint['model_state_dict'])
#      25 print("체크포인트 불러오기 완료!")
#
# File ~\Documents\Smart-energy-optimizer\venv\Lib\site-packages\torch\serialization.py:1479, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1476 if "encoding" not in pickle_load_args.keys():
#    1477     pickle_load_args["encoding"] = "utf-8"
# -> 1479 with _open_file_like(f, "rb") as opened_file:
#    1480     if _is_zipfile(opened_file):
#    1481         # The zipfile reader is going to advance the current file position.
#    1482         # If we want to actually tail call to torch.jit.load, we need to
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Shinhwa\Documents\Smart-energy-optimizer

# %%
checkpoint_path = r'C:\Users\Shinhwa\Documents\Smart-energy-optimizer\checkpoint.pth'
checkpoint = torch.load(checkpoint_path)
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 checkpoint_path = r'C:\Users\Shinhwa\Documents\Smart-energy-optimizer\checkpoint.pth'
# ----> 2 checkpoint = torch.load(checkpoint_path)
#       3 model.load_state_dict(checkpoint['model_state_dict'])
#
# File ~\Documents\Smart-energy-optimizer\venv\Lib\site-packages\torch\serialization.py:1479, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1476 if "encoding" not in pickle_load_args.keys():
#    1477     pickle_load_args["encoding"] = "utf-8"
# -> 1479 with _open_file_like(f, "rb") as opened_file:
#    1480     if _is_zipfile(opened_file):
#    1481         # The zipfile reader is going to advance the current file position.
#    1482         # If we want to actually tail call to torch.jit.load, we need to
#    1483         # reset back to the original position.
# ...

# %%
import os

checkpoint_path = r'C:\Users\Shinhwa\Documents\Smart-energy-optimizer\checkpoint.pth'
print(os.path.exists(checkpoint_path))
# Out:
# False

# %%
import os

folder = r'C:\Users\Shinhwa\Documents\Smart-energy-optimizer'
print(os.listdir(folder))
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', 'LICENSE', 'README.md', 'Untitled.ipynb', 'venv']

# %%
import torch

# 예시 모델 및 옵티마이저 생성
model = MyLSTMModel(input_size=10, hidden_size=20, num_layers=2, output_size=1)
optimizer = torch.optim.Adam(model.parameters())

# 학습 도중에 체크포인트 저장하기
checkpoint = {
    'epoch': 10,  # 현재 epoch
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    # 필요한 추가 정보
}

torch.save(checkpoint, 'checkpoint.pth')

# %%
import torch

# 모델 클래스 정의 (이전에 만든 모델과 같아야 합니다)
class MyLSTMModel(torch.nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super().__init__()
        self.lstm = torch.nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = torch.nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# 모델 객체 생성
model = MyLSTMModel(input_size=10, hidden_size=20, num_layers=2, output_size=1)

# 체크포인트 파일 경로
checkpoint_path = 'checkpoint.pth'

# 체크포인트 불러오기
checkpoint = torch.load(checkpoint_path)
model.load_state_dict(checkpoint['model_state_dict'])

print("체크포인트 불러오기 완료!")
# Out:
# 체크포인트 불러오기 완료!

# %%
import numpy as np
import pandas as pd
import torch
from torch.utils.data import TensorDataset, DataLoader

# 1. 샘플 에너지 소비 데이터 생성 (100일간 하루 1개 데이터)
np.random.seed(42)
days = 100
base_consumption = 50  # 기본 소비량
noise = np.random.normal(0, 5, days)  # 랜덤 노이즈
trend = np.linspace(0, 10, days)  # 약간 증가하는 추세
data = base_consumption + trend + noise

# 2. pandas DataFrame으로 변환 (날짜 포함)
dates = pd.date_range(start='2023-01-01', periods=days)
df = pd.DataFrame({'date': dates, 'value': data})

print(df.head())

# 3. 시계열 윈도우 생성 함수
def create_sequences(data, seq_length):
    xs = []
    ys = []
    for i in range(len(data) - seq_length):
        x = data[i:(i + seq_length)]
        y = data[i + seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

seq_length = 10
values = df['value'].values
X, y = create_sequences(values, seq_length)

print(X.shape, y.shape)  # (샘플수, seq_length), (샘플수,)

# 4. 토치 텐서로 변환 및 DataLoader 준비
X_tensor = torch.tensor(X, dtype=torch.float32).unsqueeze(-1)  # (샘플, seq_len, 1)
y_tensor = torch.tensor(y, dtype=torch.float32).unsqueeze(-1)  # (샘플, 1)

train_size = int(len(X_tensor) * 0.8)
val_size = len(X_tensor) - train_size

train_dataset = TensorDataset(X_tensor[:train_size], y_tensor[:train_size])
val_dataset = TensorDataset(X_tensor[train_size:], y_tensor[train_size:])

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)

print(f"Train samples: {len(train_dataset)}, Validation samples: {len(val_dataset)}")
# Out:
#         date      value
# 0 2023-01-01  52.483571
# 1 2023-01-02  49.409689
# 2 2023-01-03  53.440463
# 3 2023-01-04  57.918180
# 4 2023-01-05  49.233274
# (90, 10) (90,)
# Train samples: 72, Validation samples: 18

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# 시드 고정 (재현 가능성)
np.random.seed(42)

# 100일치 에너지 사용량 데이터 생성
days = 100
base_consumption = np.sin(np.arange(days) * (2 * np.pi / 30)) * 5 + 20  # 계절성 + 기본값
noise = np.random.normal(0, 1, size=days)  # 노이즈 추가
data = base_consumption + noise

# 시계열 데이터프레임
df = pd.DataFrame({'consumption': data})
plt.plot(df['consumption'])
plt.title("가짜 에너지 소비량 (100일)")
plt.xlabel("일")
plt.ylabel("소비량 (kWh)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 4
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 import tensorflow as tf
#       5 from tensorflow.keras.models import Sequential
#       6 from tensorflow.keras.layers import LSTM, Dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
# ERROR: No matching distribution found for tensorflow

# %%
# !pip install tensorflow
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
# ERROR: No matching distribution found for tensorflow

# %%
pip install torch pandas matplotlib scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

# 100일치 소비량 생성 (시즌성 + 트렌드 + 노이즈)
days = 100
time = np.arange(days)
baseline = 50
trend = time * 0.1
seasonality = 10 * np.sin(2 * np.pi * time / 30)
noise = np.random.normal(0, 2, size=days)
energy_usage = baseline + trend + seasonality + noise

# DataFrame으로 변환
df = pd.DataFrame({'day': time, 'usage': energy_usage})

# 시각화
plt.figure(figsize=(10, 4))
plt.plot(df['day'], df['usage'], label='Energy Usage')
plt.xlabel('Day')
plt.ylabel('kWh')
plt.title('Synthetic Energy Consumption')
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# 0~1 사이로 정규화
scaler = MinMaxScaler()
usage_scaled = scaler.fit_transform(df[['usage']])

# 이전 10일 데이터를 사용해 다음 1일 예측
def create_sequences(data, window_size=10):
    xs, ys = [], []
    for i in range(len(data) - window_size):
        x = data[i:i+window_size]
        y = data[i+window_size]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

X, y = create_sequences(usage_scaled, window_size=10)

print("X shape:", X.shape)  # (90, 10, 1)
print("y shape:", y.shape)  # (90, 1)
# Out:
# X shape: (90, 10, 1)
# y shape: (90, 1)

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# 텐서 변환
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32)

# 데이터셋 준비
dataset = TensorDataset(X_tensor, y_tensor)
dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

# 모델 정의
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=64):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = out[:, -1, :]  # 마지막 타임스텝만 사용
        return self.fc(out)

model = LSTMModel()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
epochs = 100
losses = []

for epoch in range(epochs):
    for xb, yb in dataloader:
        pred = model(xb)
        loss = criterion(pred, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    losses.append(loss.item())
    if (epoch+1) % 10 == 0:
        print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")

# 학습 손실 시각화
plt.plot(losses)
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.grid()
plt.show()
# Out:
# Epoch 10, Loss: 0.0088
# Epoch 20, Loss: 0.0046
# Epoch 30, Loss: 0.0052
# Epoch 40, Loss: 0.0108
# Epoch 50, Loss: 0.0080
# Epoch 60, Loss: 0.0075
# Epoch 70, Loss: 0.0044
# Epoch 80, Loss: 0.0049
# Epoch 90, Loss: 0.0080
# Epoch 100, Loss: 0.0058

# %%
# 전체 데이터 예측
with torch.no_grad():
    preds = model(X_tensor).numpy()

# 역정규화
y_true = scaler.inverse_transform(y)
y_pred = scaler.inverse_transform(preds)

# 시각화
plt.figure(figsize=(10, 4))
plt.plot(y_true, label='True')
plt.plot(y_pred, label='Predicted')
plt.title('Energy Usage Prediction')
plt.xlabel('Day')
plt.ylabel('kWh')
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

print(f"MAE: {mae:.3f}")
print(f"RMSE: {rmse:.3f}")
# Out:
# MAE: 2.022
# RMSE: 2.458

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# 오차 계산
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
print(f"MAE: {mae:.3f}, RMSE: {rmse:.3f}")

# CSV 저장
results = pd.DataFrame({
    'actual': y_true.flatten(),
    'predicted': y_pred.flatten()
})
results.to_csv('energy_predictions.csv', index=False)
print("CSV 파일 저장 완료!")
# Out:
# MAE: 2.022, RMSE: 2.458
# CSV 파일 저장 완료!

# %%
import pandas as pd
import numpy as np
import time

# 가상의 원본 데이터 (100일치)
np.random.seed(42)
base_date = pd.date_range(start="2023-01-01", periods=100, freq='D')
energy_data = pd.DataFrame({
    "timestamp": base_date,
    "consumption": 50 + np.random.normal(0, 10, 100).cumsum()  # 누적형으로 변동
})

# 가상의 실시간 흐름 시뮬레이션
def simulate_streaming(data, window_size=10, delay=0.5):
    for i in range(window_size, len(data)):
        recent = data.iloc[i-window_size:i]
        next_day = data.iloc[i]
        yield recent["consumption"].values.reshape(1, window_size, 1), next_day["consumption"]
        time.sleep(delay)  # 실제 스트림처럼 0.5초 대기 (테스트용)

# %%
for x_input, actual in simulate_streaming(energy_data):
    prediction = model.predict(x_input, verbose=0)
    print(f"예측값: {prediction[0][0]:.2f}, 실제값: {actual:.2f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 for x_input, actual in simulate_streaming(energy_data):
# ----> 2     prediction = model.predict(x_input, verbose=0)
#       3     print(f"예측값: {prediction[0][0]:.2f}, 실제값: {actual:.2f}")
#
# File ~\Documents\Smart-energy-optimizer\venv\Lib\site-packages\torch\nn\modules\module.py:1940, in Module.__getattr__(self, name)
#    1938     if name in modules:
#    1939         return modules[name]
# -> 1940 raise AttributeError(
#    1941     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1942 )
#
# AttributeError: 'LSTMModel' object has no attribute 'predict'

# %%
import torch

model.eval()  # 추론 모드 전환

for x_input, actual in simulate_streaming(energy_data):
    x_tensor = torch.tensor(x_input, dtype=torch.float32)  # numpy → tensor
    with torch.no_grad():  # gradient 추적 끄기 (메모리 절약)
        prediction = model(x_tensor)
    print(f"예측값: {prediction.item():.2f}, 실제값: {actual:.2f}")
# Out:
# 예측값: 4.52, 실제값: 90.17
# 예측값: 4.51, 실제값: 85.51
# 예측값: 4.48, 실제값: 87.93
# 예측값: 4.38, 실제값: 68.80
# 예측값: 4.27, 실제값: 51.55
# 예측값: 4.27, 실제값: 45.93
# 예측값: 4.42, 실제값: 35.80
# 예측값: 4.46, 실제값: 38.94
# 예측값: 4.49, 실제값: 29.86
# 예측값: 4.47, 실제값: 15.74
# 예측값: 4.32, 실제값: 30.40
# 예측값: 4.49, 실제값: 28.14
# 예측값: 4.48, 실제값: 28.81
# 예측값: 4.49, 실제값: 14.57
# 예측값: 4.30, 실제값: 9.12
# 예측값: 4.12, 실제값: 10.23
# 예측값: 4.16, 실제값: -1.28
# 예측값: 2.51, 실제값: 2.48
# 예측값: 2.73, 실제값: -3.53
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 5
#       1 import torch
#       3 model.eval()  # 추론 모드 전환
# ----> 5 for x_input, actual in simulate_streaming(energy_data):
#       6     x_tensor = torch.tensor(x_input, dtype=torch.float32)  # numpy → tensor
#       7     with torch.no_grad():  # gradient 추적 끄기 (메모리 절약)
#
# Cell In[8], line 19, in simulate_streaming(data, window_size, delay)
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

def evaluate_model(model, data, sequence_length):
    X, y_true = [], []

    for i in range(sequence_length, len(data)):
        X.append(data[i-sequence_length:i])
        y_true.append(data[i])

    X = np.array(X)
    y_true = np.array(y_true)

    y_pred = model(torch.tensor(X, dtype=torch.float32)).detach().numpy()

    # 정확도 지표 계산
    mae = mean_absolute_error(y_true, y_pred)
    rmse = mean_squared_error(y_true, y_pred, squared=False)

    print(f"MAE (Mean Absolute Error): {mae:.4f}")
    print(f"RMSE (Root Mean Squared Error): {rmse:.4f}")

    return y_true, y_pred

# %%
def plot_predictions(y_true, y_pred):
    plt.figure(figsize=(12, 6))
    plt.plot(y_true, label='Actual')
    plt.plot(y_pred, label='Predicted')
    plt.title('Actual vs Predicted Energy Consumption')
    plt.xlabel('Time')
    plt.ylabel('Energy Usage')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# 시퀀스 길이 동일하게 설정
sequence_length = 10  

y_true, y_pred = evaluate_model(model, energy_data, sequence_length)
plot_predictions(y_true, y_pred)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Smart-energy-optimizer\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 10
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 4
#       1 # 시퀀스 길이 동일하게 설정
# ...

# %%
def evaluate_model(model, data, sequence_length):
    model.eval()
    X, y_true = [], []

    for i in range(sequence_length, len(data)):
        X.append(data[i-sequence_length:i])
        y_true.append(data.iloc[i])  # <- 여기 수정!

    X = np.array(X)
    y_true = np.array(y_true)

    with torch.no_grad():
        X_tensor = torch.tensor(X, dtype=torch.float32)
        predictions = model(X_tensor).numpy()

    return y_true, predictions

# %%
def plot_predictions(y_true, y_pred):
    plt.figure(figsize=(12, 6))
    plt.plot(y_true, label='Actual')
    plt.plot(y_pred, label='Predicted')
    plt.title('Actual vs Predicted Energy Consumption')
    plt.xlabel('Time')
    plt.ylabel('Energy Usage')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# 시퀀스 길이 동일하게 설정
sequence_length = 10  

y_true, y_pred = evaluate_model(model, energy_data, sequence_length)
plot_predictions(y_true, y_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 # 시퀀스 길이 동일하게 설정
#       2 sequence_length = 10
# ----> 4 y_true, y_pred = evaluate_model(model, energy_data, sequence_length)
#       5 plot_predictions(y_true, y_pred)
#
# Cell In[14], line 13, in evaluate_model(model, data, sequence_length)
#      10 y_true = np.array(y_true)
#      12 with torch.no_grad():
# ---> 13     X_tensor = torch.tensor(X, dtype=torch.float32)
#      14     predictions = model(X_tensor).numpy()
#      16 return y_true, predictions
#
# TypeError: can't convert np.ndarray of type numpy.object_. The only supported types are: float64, float32, float16, complex64, complex128, int64, int32, int16, int8, uint64, uint32, uint16, uint8, and bool.

# %%
def evaluate_model(model, data, sequence_length):
    X = []
    y_true = []

    for i in range(sequence_length, len(data)):
        X.append(data[i-sequence_length:i])
        y_true.append(data[i])

    X = np.array(X, dtype=np.float32)  # 이 부분이 중요!
    y_true = np.array(y_true, dtype=np.float32)

    with torch.no_grad():
        X_tensor = torch.tensor(X, dtype=torch.float32)
        predictions = model(X_tensor).numpy()

    return y_true, predictions

# %%
def plot_predictions(y_true, y_pred):
    plt.figure(figsize=(12, 6))
    plt.plot(y_true, label='Actual')
    plt.plot(y_pred, label='Predicted')
    plt.title('Actual vs Predicted Energy Consumption')
    plt.xlabel('Time')
    plt.ylabel('Energy Usage')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# 시퀀스 길이 동일하게 설정
sequence_length = 10  

y_true, y_pred = evaluate_model(model, energy_data, sequence_length)
plot_predictions(y_true, y_pred)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Smart-energy-optimizer\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 10
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 4
#       1 # 시퀀스 길이 동일하게 설정
# ...

# %%
def evaluate_model(model, data, sequence_length):
    X, y_true = [], []

    # 정규화된 에너지 소비량 컬럼만 사용
    values = data['consumption'].values.astype(np.float32)

    for i in range(sequence_length, len(values)):
        X.append(values[i-sequence_length:i])
        y_true.append(values[i])

    X = np.array(X, dtype=np.float32)
    y_true = np.array(y_true, dtype=np.float32)

    with torch.no_grad():
        X_tensor = torch.tensor(X, dtype=torch.float32)
        predictions = model(X_tensor).numpy()

    return y_true, predictions

# %%
def detect_anomalies(data, threshold=1.5):
    """
    IQR 기반 이상치 탐지
    """
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - threshold * IQR
    upper_bound = Q3 + threshold * IQR
    anomalies = (data < lower_bound) | (data > upper_bound)
    return anomalies

# %%
def generate_optimization_suggestions(df, predictions, sequence_length=10):
    df = df.copy()
    df['prediction'] = [None]*sequence_length + predictions.tolist()
    
    # 소비량 이상치 탐지
    df['is_anomaly'] = detect_anomalies(df['energy_consumption'])

    # 시간대별 평균 소비
    df['hour'] = df['timestamp'].dt.hour
    hourly_avg = df.groupby('hour')['energy_consumption'].mean()

    # 예: 가장 많이 쓰는 시간대 찾기
    high_usage_hours = hourly_avg[hourly_avg > hourly_avg.mean() + hourly_avg.std()].index.tolist()
    
    suggestions = []
    if high_usage_hours:
        suggestions.append(f"⚠️ 에너지 소비가 많은 시간대: {high_usage_hours}시. 가능한 피하세요.")
    
    if df['is_anomaly'].sum() > 0:
        suggestions.append(f"🚨 최근 {df['is_anomaly'].sum()}건의 이상 소비가 탐지되었습니다.")
    
    # 예측된 소비가 특정 구간에서 급증할 때 알림
    if df['prediction'].notna().sum():
        predicted_peak = df['prediction'].rolling(3).mean().idxmax()
        if predicted_peak:
            peak_time = df.loc[predicted_peak, 'timestamp']
            suggestions.append(f"📈 {peak_time} 시간대에 높은 소비가 예측됩니다. 절약 권장!")

    return suggestions

# %%
|suggestions = generate_optimization_suggestions(energy_data, y_pred)
for s in suggestions:
    print(s)
# Out:
#   Cell In[23], line 1
#     |suggestions = generate_optimization_suggestions(energy_data, y_pred)
#     ^
# SyntaxError: invalid syntax

# %%
suggestions = generate_optimization_suggestions(energy_data, y_pred)
for s in suggestions:
    print(s)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Smart-energy-optimizer\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'energy_consumption'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ...

# %%
print(energy_data.columns)
# Out:
# Index(['timestamp', 'consumption'], dtype='object')

# %%
def generate_optimization_suggestions(df, predictions, sequence_length=10):
    df = df.copy()
    df['prediction'] = [None]*sequence_length + predictions.tolist()
    
    df['is_anomaly'] = detect_anomalies(df['consumption'])

    df['hour'] = df['timestamp'].dt.hour
    hourly_avg = df.groupby('hour')['consumption'].mean()

    high_usage_hours = hourly_avg[hourly_avg > hourly_avg.mean() + hourly_avg.std()].index.tolist()
    
    suggestions = []
    if high_usage_hours:
        suggestions.append(f"⚠️ 에너지 소비가 많은 시간대: {high_usage_hours}시. 가능한 피하세요.")
    
    if df['is_anomaly'].sum() > 0:
        suggestions.append(f"🚨 최근 {df['is_anomaly'].sum()}건의 이상 소비가 탐지되었습니다.")
    
    if df['prediction'].notna().sum():
        predicted_peak = df['prediction'].rolling(3).mean().idxmax()
        if predicted_peak:
            peak_time = df.loc[predicted_peak, 'timestamp']
            suggestions.append(f"📈 {peak_time} 시간대에 높은 소비가 예측됩니다. 절약 권장!")

    return suggestions

# %%
suggestions = generate_optimization_suggestions(energy_data, y_pred)
for s in suggestions:
    print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File ~\Documents\Smart-energy-optimizer\venv\Lib\site-packages\pandas\core\window\rolling.py:371, in BaseWindow._prep_values(self, values)
#     370     else:
# --> 371         values = ensure_float64(values)
#     372 except (ValueError, TypeError) as err:
#
# File pandas/_libs/algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: setting an array element with a sequence.
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
def generate_optimization_suggestions(df, predictions, sequence_length=10):
    df = df.copy()
    # 1차원 숫자 리스트로 변환해서 넣기
    df['prediction'] = [None]*sequence_length + np.array(predictions).flatten().tolist()
    
    df['is_anomaly'] = detect_anomalies(df['consumption'])
    df['hour'] = df['timestamp'].dt.hour
    hourly_avg = df.groupby('hour')['consumption'].mean()

    high_usage_hours = hourly_avg[hourly_avg > hourly_avg.mean() + hourly_avg.std()].index.tolist()
    
    suggestions = []
    if high_usage_hours:
        suggestions.append(f"⚠️ 에너지 소비가 많은 시간대: {high_usage_hours}시. 가능한 피하세요.")
    
    if df['is_anomaly'].sum() > 0:
        suggestions.append(f"🚨 최근 {df['is_anomaly'].sum()}건의 이상 소비가 탐지되었습니다.")
    
    if df['prediction'].notna().sum():
        predicted_peak = df['prediction'].rolling(3).mean().idxmax()
        if predicted_peak:
            peak_time = df.loc[predicted_peak, 'timestamp']
            suggestions.append(f"📈 {peak_time} 시간대에 높은 소비가 예측됩니다. 절약 권장!")

    return suggestions

# %%
suggestions = generate_optimization_suggestions(energy_data, y_pred)
for s in suggestions:
    print(s)
# Out:
# 📈 2023-03-11 00:00:00 시간대에 높은 소비가 예측됩니다. 절약 권장!
